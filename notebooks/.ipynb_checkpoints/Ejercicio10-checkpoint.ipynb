# %%
rounds = [
{
'theme': 'Entrada',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Santiago': {'judge_1': 6, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 8},
}
},
{
'theme': 'Plato principal',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Mateo': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Camila': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Lucía': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
}
},
{
'theme': 'Postre',
'scores': {
'Valentina': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Mateo': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Santiago': {'judge_1': 7, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
}
},
{
'theme': 'Cocina internacional',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 9,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Santiago': {'judge_1': 8, 'judge_2': 9,
'judge_3': 7},
'Lucía': {'judge_1': 7, 'judge_2': 7,
'judge_3': 8},
}
},
{
'theme': 'Final libre',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 8,
'judge_3': 9},
'Mateo': {'judge_1': 8, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 7, 'judge_2': 7,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 7},
}
}
]

# %%
print(rounds)
# Out:
# [{'theme': 'Entrada', 'scores': {'Valentina': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}, 'Mateo': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}, 'Camila': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}, 'Santiago': {'judge_1': 6, 'judge_2': 7, 'judge_3': 6}, 'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 8}}}, {'theme': 'Plato principal', 'scores': {'Valentina': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}, 'Mateo': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}, 'Camila': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7}, 'Santiago': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8}, 'Lucía': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}}}, {'theme': 'Postre', 'scores': {'Valentina': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}, 'Mateo': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}, 'Camila': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}, 'Santiago': {'judge_1': 7, 'judge_2': 7, 'judge_3': 6}, 'Lucía': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9}}}, {'theme': 'Cocina internacional', 'scores': {'Valentina': {'judge_1':
# ...

# %%
estadisticas = {}
for ronda in rounds:
    print("Ronda:", ronda['theme'])

    for participante, jueces in ronda['scores'].items():
        print(participante, jueces)
# Out:
# Ronda: Entrada
# Valentina {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}
# Mateo {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}
# Camila {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}
# Santiago {'judge_1': 6, 'judge_2': 7, 'judge_3': 6}
# Lucía {'judge_1': 8, 'judge_2': 8, 'judge_3': 8}
# Ronda: Plato principal
# Valentina {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}
# Mateo {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}
# Camila {'judge_1': 7, 'judge_2': 6, 'judge_3': 7}
# Santiago {'judge_1': 9, 'judge_2': 8, 'judge_3': 8}
# Lucía {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}
# Ronda: Postre
# Valentina {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}
# Mateo {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}
# Camila {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}
# Santiago {'judge_1': 7, 'judge_2': 7, 'judge_3': 6}
# Lucía {'judge_1': 9, 'judge_2': 9, 'judge_3': 9}
# Ronda: Cocina internacional
# Valentina {'judge_1': 8, 'judge_2': 9, 'judge_3': 9}
# Mateo {'judge_1': 7, 'judge_2': 6, 'judge_3': 7}
# ...

# %%
estadisticas = {}
for ronda in rounds:
    print("Ronda:", ronda['theme'])

    for participante, jueces in ronda['scores'].items():
        puntaje = sum(jueces.values())
        print(participante, "=", puntaje)
# Out:
# Ronda: Entrada
# Valentina = 24
# Mateo = 22
# Camila = 26
# Santiago = 19
# Lucía = 24
# Ronda: Plato principal
# Valentina = 26
# Mateo = 24
# Camila = 20
# Santiago = 25
# Lucía = 22
# Ronda: Postre
# Valentina = 22
# Mateo = 26
# Camila = 24
# Santiago = 20
# Lucía = 27
# Ronda: Cocina internacional
# Valentina = 26
# Mateo = 20
# Camila = 25
# Santiago = 24
# Lucía = 22
# Ronda: Final libre
# Valentina = 26
# Mateo = 25
# Camila = 21
# Santiago = 27
# Lucía = 23

# %%
estadisticas = {}
for ronda in rounds:
    print("Ronda:", ronda['theme'])

    for participante, jueces in ronda['scores'].items():
        puntaje = sum(jueces.values())

        if participante not in estadisticas:
            estadisticas[participante] = {
                "puntaje_total":0,
                "rondas_ganadas":0,
                "mejor_ronda":0,
                "promedio":0,
            }

        estadisticas[participante]["puntaje_total"]+= puntaje
        estadisticas[participante]["rondas_ganadas"] += 1

        if puntaje > estadisticas[participante]["mejor_ronda"]:
            estadisticas[participante]["mejor_ronda"] = puntaje
    print (estadisticas)
# Out:
# Ronda: Entrada
# {'Valentina': {'puntaje_total': 24, 'rondas_ganadas': 1, 'mejor_ronda': 24, 'promedio': 0}, 'Mateo': {'puntaje_total': 22, 'rondas_ganadas': 1, 'mejor_ronda': 22, 'promedio': 0}, 'Camila': {'puntaje_total': 26, 'rondas_ganadas': 1, 'mejor_ronda': 26, 'promedio': 0}, 'Santiago': {'puntaje_total': 19, 'rondas_ganadas': 1, 'mejor_ronda': 19, 'promedio': 0}, 'Lucía': {'puntaje_total': 24, 'rondas_ganadas': 1, 'mejor_ronda': 24, 'promedio': 0}}
# Ronda: Plato principal
# {'Valentina': {'puntaje_total': 50, 'rondas_ganadas': 2, 'mejor_ronda': 26, 'promedio': 0}, 'Mateo': {'puntaje_total': 46, 'rondas_ganadas': 2, 'mejor_ronda': 24, 'promedio': 0}, 'Camila': {'puntaje_total': 46, 'rondas_ganadas': 2, 'mejor_ronda': 26, 'promedio': 0}, 'Santiago': {'puntaje_total': 44, 'rondas_ganadas': 2, 'mejor_ronda': 25, 'promedio': 0}, 'Lucía': {'puntaje_total': 46, 'rondas_ganadas': 2, 'mejor_ronda': 24, 'promedio': 0}}
# Ronda: Postre
# ...

# %%
estadisticas = {}
for ronda in rounds:
    print("Ronda:", ronda['theme'])

    puntajes_ronda = {}
    
    for participante, jueces in ronda['scores'].items():
        puntaje = sum(jueces.values())

        if participante not in estadisticas:
            estadisticas[participante] = {
                "puntaje_total":0,
                "rondas_ganadas":0,
                "mejor_ronda":0,
                "promedio":0,
            }

        estadisticas[participante]["puntaje_total"]+= puntaje
        estadisticas[participante]["promedio"] += 1

        if puntaje > estadisticas[participante]["mejor_ronda"]:
            estadisticas[participante]["mejor_ronda"] = puntaje

        puntajes_ronda[participante] = puntaje
    ganador = max(puntajes_ronda, key=puntajes_ronda.get)
    estadisticas[ganador]["rondas_ganadas"] += 1
    
    print ("Ganador:", ganador)
# Out:
# Ronda: Entrada
# Ganador: Camila
# Ronda: Plato principal
# Ganador: Valentina
# Ronda: Postre
# Ganador: Lucía
# Ronda: Cocina internacional
# Ganador: Valentina
# Ronda: Final libre
# Ganador: Santiago

# %%
estadisticas = {}
for ronda in rounds:
    print("Ronda:", ronda['theme'])

    puntajes_ronda = {}
    
    for participante, jueces in ronda['scores'].items():
        puntaje = sum(jueces.values())

        if participante not in estadisticas:
            estadisticas[participante] = {
                "puntaje_total":0,
                "rondas_ganadas":0,
                "mejor_ronda":0,
                "promedio":0,
            }

        estadisticas[participante]["puntaje_total"]+= puntaje
        estadisticas[participante]["promedio"] += 1

        if puntaje > estadisticas[participante]["mejor_ronda"]:
            estadisticas[participante]["mejor_ronda"] = puntaje

        puntajes_ronda[participante] = puntaje
        
    ganador = max(puntajes_ronda, key=puntajes_ronda.get)
    estadisticas[ganador]["rondas_ganadas"] += 1
    
    print ("Ganador:", ganador)
    print("-" * 40)
    
for participante, datos in estadisticas.items():
    datos["promedio"] = round(datos["puntaje_total"] / datos["promedio"],1)

ordenados = sorted(estadisticas.items(), key=lambda x: x[1]["puntaje_total"], reverse=True)

print("Tabla final:" )
print("Cocinero | Puntaje total | Rondas ganadas | Mejor ronda | Promedio")

for participante, datos in ordenados:
    print(
        participante,
        "|",
        datos["puntaje_total"],
        "|",
        datos["rondas_ganadas"],
        "|",
        datos["mejor_ronda"],
        "|",
        datos["promedio"]
    )
# Out:
# Ronda: Entrada
# Ganador: Camila
# ----------------------------------------
# Ronda: Plato principal
# Ganador: Valentina
# ----------------------------------------
# Ronda: Postre
# Ganador: Lucía
# ----------------------------------------
# Ronda: Cocina internacional
# Ganador: Valentina
# ----------------------------------------
# Ronda: Final libre
# Ganador: Santiago
# ----------------------------------------
# Tabla final:
# Cocinero | Puntaje total | Rondas ganadas | Mejor ronda | Promedio
# Valentina | 124 | 2 | 26 | 24.8
# Lucía | 118 | 1 | 27 | 23.6
# Mateo | 117 | 0 | 26 | 23.4
# Camila | 116 | 1 | 26 | 23.2
# Santiago | 115 | 1 | 27 | 23.0
